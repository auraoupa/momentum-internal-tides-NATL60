# %%
import xarray as xr
import sys
sys.path.insert(0,"/home/albert/lib/python")

import numpy as np
sys.path.insert(0,"/home/albert/Work/git/xscale")
import xscale

# %%
import xscale.signal.generator as xgen

# %%
foo = xgen.example_xyt()

# %%
foo.isel(y=40, x=40).plot()

# %%
wt = foo.window

# %%
wt.set()

# %%
print(wt)
# Out:
# Window [order->{'y': 128, 'x': 128, 'time': 100}, cutoff->{'y': None, 'x': None, 'time': None}, dx->{'y': 0.049473900056532176, 'x': 0.049473900056532176, 'time': 86400.0}, window->{'y': 'boxcar', 'x': 'boxcar', 'time': 'boxcar'}]

# %%
wt.set(dim='time',cutoff=10,dx=1)

# %%
print(wt)
# Out:
# Window [order->{'time': 100}, cutoff->{'time': 10}, dx->{'time': 1}, window->{'time': 'boxcar'}]

# %%
wt.plot()

# %%
res=wt.convolve()

# %%
foo.isel(y=40, x=40).plot(label="Raw data")
res.isel(y=40, x=40).plot(label="Filtered data", ls="--")
