# %%
## path for mdules

import sys
sys.path.insert(0,"/home/albert/lib/python")

import numpy as np
import xarray as xr
import glob

from netCDF4 import Dataset

sys.path.insert(0,"/home/albert/Work/git/xscale")
import xscale
import xscale.spectral.fft as xfft

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import numpy.ma as ma

import matplotlib.cm as mplcm

seq_cmap = mplcm.Blues
div_cmap = mplcm.seismic

import matplotlib.pyplot as plt
from datetime import date


# %matplotlib inline

# %%
#Datasets

fileff='/mnt/albert/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-I/surf_mesh_mask_eNATL60_3.6.nc'

#tide simulation
dirtide='/mnt/albert/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLBT02-S/1h/ACO/'

fileUwavetide100m=dirtide+'eNATL60ACO-BLBT02_1h_gridU100m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide200m=dirtide+'eNATL60ACO-BLBT02_1h_gridU200m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide300m=dirtide+'eNATL60ACO-BLBT02_1h_gridU300m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide400m=dirtide+'eNATL60ACO-BLBT02_1h_gridU400m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide500m=dirtide+'eNATL60ACO-BLBT02_1h_gridU500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide1000m=dirtide+'eNATL60ACO-BLBT02_1h_gridU1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide1500m=dirtide+'eNATL60ACO-BLBT02_1h_gridU1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide2000m=dirtide+'eNATL60ACO-BLBT02_1h_gridU2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide2500m=dirtide+'eNATL60ACO-BLBT02_1h_gridU2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide3000m=dirtide+'eNATL60ACO-BLBT02_1h_gridU3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavetide3500m=dirtide+'eNATL60ACO-BLBT02_1h_gridU3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

fileVwavetide100m=dirtide+'eNATL60ACO-BLBT02_1h_gridV100m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide200m=dirtide+'eNATL60ACO-BLBT02_1h_gridV200m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide300m=dirtide+'eNATL60ACO-BLBT02_1h_gridV300m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide400m=dirtide+'eNATL60ACO-BLBT02_1h_gridV400m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide500m=dirtide+'eNATL60ACO-BLBT02_1h_gridV500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide1000m=dirtide+'eNATL60ACO-BLBT02_1h_gridV1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide1500m=dirtide+'eNATL60ACO-BLBT02_1h_gridV1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide2000m=dirtide+'eNATL60ACO-BLBT02_1h_gridV2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide2500m=dirtide+'eNATL60ACO-BLBT02_1h_gridV2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide3000m=dirtide+'eNATL60ACO-BLBT02_1h_gridV3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavetide3500m=dirtide+'eNATL60ACO-BLBT02_1h_gridV3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

fileWwavetide100m=dirtide+'eNATL60ACO-BLBT02_1h_gridW100m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide200m=dirtide+'eNATL60ACO-BLBT02_1h_gridW200m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide300m=dirtide+'eNATL60ACO-BLBT02_1h_gridW300m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide400m=dirtide+'eNATL60ACO-BLBT02_1h_gridW400m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide500m=dirtide+'eNATL60ACO-BLBT02_1h_gridW500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide1000m=dirtide+'eNATL60ACO-BLBT02_1h_gridW1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide1500m=dirtide+'eNATL60ACO-BLBT02_1h_gridW1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide2000m=dirtide+'eNATL60ACO-BLBT02_1h_gridW2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide2500m=dirtide+'eNATL60ACO-BLBT02_1h_gridW2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide3000m=dirtide+'eNATL60ACO-BLBT02_1h_gridW3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavetide3500m=dirtide+'eNATL60ACO-BLBT02_1h_gridW3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

filebuoywavetide100m=dirtide+'eNATL60ACO-BLBT02_1h_buoy100m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide200m=dirtide+'eNATL60ACO-BLBT02_1h_buoy200m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide300m=dirtide+'eNATL60ACO-BLBT02_1h_buoy300m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide400m=dirtide+'eNATL60ACO-BLBT02_1h_buoy400m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide500m=dirtide+'eNATL60ACO-BLBT02_1h_buoy500m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide1000m=dirtide+'eNATL60ACO-BLBT02_1h_buoy1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide1500m=dirtide+'eNATL60ACO-BLBT02_1h_buoy1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide2000m=dirtide+'eNATL60ACO-BLBT02_1h_buoy2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide2500m=dirtide+'eNATL60ACO-BLBT02_1h_buoy2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide3000m=dirtide+'eNATL60ACO-BLBT02_1h_buoy3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavetide3500m=dirtide+'eNATL60ACO-BLBT02_1h_buoy3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

fileN2tide=dirtide+'eNATL60ACO-BLBT02_1h_20090710_20090714_N2_20090714-20090714.nc'


#no tide simulation
dirnotide='/mnt/albert/equipes/IGE/meom/workdir/albert/eNATL60/eNATL60-BLB002-S/1h/ACO/'

fileUwavenotide100m=dirnotide+'eNATL60ACO-BLB002_1h_gridU100m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide200m=dirnotide+'eNATL60ACO-BLB002_1h_gridU200m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide300m=dirnotide+'eNATL60ACO-BLB002_1h_gridU300m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide400m=dirnotide+'eNATL60ACO-BLB002_1h_gridU400m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide500m=dirnotide+'eNATL60ACO-BLB002_1h_gridU500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide1000m=dirnotide+'eNATL60ACO-BLB002_1h_gridU1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide1500m=dirnotide+'eNATL60ACO-BLB002_1h_gridU1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide2000m=dirnotide+'eNATL60ACO-BLB002_1h_gridU2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide2500m=dirnotide+'eNATL60ACO-BLB002_1h_gridU2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide3000m=dirnotide+'eNATL60ACO-BLB002_1h_gridU3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileUwavenotide3500m=dirnotide+'eNATL60ACO-BLB002_1h_gridU3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

fileVwavenotide100m=dirnotide+'eNATL60ACO-BLB002_1h_gridV100m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide200m=dirnotide+'eNATL60ACO-BLB002_1h_gridV200m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide300m=dirnotide+'eNATL60ACO-BLB002_1h_gridV300m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide400m=dirnotide+'eNATL60ACO-BLB002_1h_gridV400m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide500m=dirnotide+'eNATL60ACO-BLB002_1h_gridV500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide1000m=dirnotide+'eNATL60ACO-BLB002_1h_gridV1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide1500m=dirnotide+'eNATL60ACO-BLB002_1h_gridV1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide2000m=dirnotide+'eNATL60ACO-BLB002_1h_gridV2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide2500m=dirnotide+'eNATL60ACO-BLB002_1h_gridV2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide3000m=dirnotide+'eNATL60ACO-BLB002_1h_gridV3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileVwavenotide3500m=dirnotide+'eNATL60ACO-BLB002_1h_gridV3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

fileWwavenotide100m=dirnotide+'eNATL60ACO-BLB002_1h_gridW100m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide200m=dirnotide+'eNATL60ACO-BLB002_1h_gridW200m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide300m=dirnotide+'eNATL60ACO-BLB002_1h_gridW300m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide400m=dirnotide+'eNATL60ACO-BLB002_1h_gridW400m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide500m=dirnotide+'eNATL60ACO-BLB002_1h_gridW500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide1000m=dirnotide+'eNATL60ACO-BLB002_1h_gridW1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide1500m=dirnotide+'eNATL60ACO-BLB002_1h_gridW1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide2000m=dirnotide+'eNATL60ACO-BLB002_1h_gridW2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide2500m=dirnotide+'eNATL60ACO-BLB002_1h_gridW2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide3000m=dirnotide+'eNATL60ACO-BLB002_1h_gridW3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
fileWwavenotide3500m=dirnotide+'eNATL60ACO-BLB002_1h_gridW3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

filebuoywavenotide100m=dirnotide+'eNATL60ACO-BLB002_1h_buoy100m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide200m=dirnotide+'eNATL60ACO-BLB002_1h_buoy200m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide300m=dirnotide+'eNATL60ACO-BLB002_1h_buoy300m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide400m=dirnotide+'eNATL60ACO-BLB002_1h_buoy400m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide500m=dirnotide+'eNATL60ACO-BLB002_1h_buoy500m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide1000m=dirnotide+'eNATL60ACO-BLB002_1h_buoy1000m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide1500m=dirnotide+'eNATL60ACO-BLB002_1h_buoy1500m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide2000m=dirnotide+'eNATL60ACO-BLB002_1h_buoy2000m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide2500m=dirnotide+'eNATL60ACO-BLB002_1h_buoy2500m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide3000m=dirnotide+'eNATL60ACO-BLB002_1h_buoy3000m_20090710-20090809_filt-n48-f76035.7005445.nc'
filebuoywavenotide3500m=dirnotide+'eNATL60ACO-BLB002_1h_buoy3500m_20090710-20090809_filt-n48-f76035.7005445.nc'

fileN2notide=dirnotide+'eNATL60ACO-BLB002_1h_20090710_20090714_N2_20090710-20090710.nc'

# %%
dsff=xr.open_dataset(fileff,chunks={'x':500,'y':500})

dsUwavetide100m=xr.open_dataset(fileUwavetide100m,chunks={'x':500,'y':500})
dsUwavetide200m=xr.open_dataset(fileUwavetide200m,chunks={'x':500,'y':500})
dsUwavetide300m=xr.open_dataset(fileUwavetide300m,chunks={'x':500,'y':500})
dsUwavetide400m=xr.open_dataset(fileUwavetide400m,chunks={'x':500,'y':500})
dsUwavetide500m=xr.open_dataset(fileUwavetide500m,chunks={'x':500,'y':500})
dsUwavetide1000m=xr.open_dataset(fileUwavetide1000m,chunks={'x':500,'y':500})
dsUwavetide1500m=xr.open_dataset(fileUwavetide1500m,chunks={'x':500,'y':500})
dsUwavetide2000m=xr.open_dataset(fileUwavetide2000m,chunks={'x':500,'y':500})
dsUwavetide2500m=xr.open_dataset(fileUwavetide2500m,chunks={'x':500,'y':500})
dsUwavetide3000m=xr.open_dataset(fileUwavetide3000m,chunks={'x':500,'y':500})
dsUwavetide3500m=xr.open_dataset(fileUwavetide3500m,chunks={'x':500,'y':500})

dsVwavetide100m=xr.open_dataset(fileVwavetide100m,chunks={'x':500,'y':500})
dsVwavetide200m=xr.open_dataset(fileVwavetide200m,chunks={'x':500,'y':500})
dsVwavetide300m=xr.open_dataset(fileVwavetide300m,chunks={'x':500,'y':500})
dsVwavetide400m=xr.open_dataset(fileVwavetide400m,chunks={'x':500,'y':500})
dsVwavetide500m=xr.open_dataset(fileVwavetide500m,chunks={'x':500,'y':500})
dsVwavetide1000m=xr.open_dataset(fileVwavetide1000m,chunks={'x':500,'y':500})
dsVwavetide1500m=xr.open_dataset(fileVwavetide1500m,chunks={'x':500,'y':500})
dsVwavetide2000m=xr.open_dataset(fileVwavetide2000m,chunks={'x':500,'y':500})
dsVwavetide2500m=xr.open_dataset(fileVwavetide2500m,chunks={'x':500,'y':500})
dsVwavetide3000m=xr.open_dataset(fileVwavetide3000m,chunks={'x':500,'y':500})
dsVwavetide3500m=xr.open_dataset(fileVwavetide3500m,chunks={'x':500,'y':500})

dsWwavetide100m=xr.open_dataset(fileWwavetide100m,chunks={'x':500,'y':500})
dsWwavetide200m=xr.open_dataset(fileWwavetide200m,chunks={'x':500,'y':500})
dsWwavetide300m=xr.open_dataset(fileWwavetide300m,chunks={'x':500,'y':500})
dsWwavetide400m=xr.open_dataset(fileWwavetide400m,chunks={'x':500,'y':500})
dsWwavetide500m=xr.open_dataset(fileWwavetide500m,chunks={'x':500,'y':500})
dsWwavetide1000m=xr.open_dataset(fileWwavetide1000m,chunks={'x':500,'y':500})
dsWwavetide1500m=xr.open_dataset(fileWwavetide1500m,chunks={'x':500,'y':500})
dsWwavetide2000m=xr.open_dataset(fileWwavetide2000m,chunks={'x':500,'y':500})
dsWwavetide2500m=xr.open_dataset(fileWwavetide2500m,chunks={'x':500,'y':500})
dsWwavetide3000m=xr.open_dataset(fileWwavetide3000m,chunks={'x':500,'y':500})
dsWwavetide3500m=xr.open_dataset(fileWwavetide3500m,chunks={'x':500,'y':500})

dsbuoywavetide100m=xr.open_dataset(filebuoywavetide100m,chunks={'x':500,'y':500})
dsbuoywavetide200m=xr.open_dataset(filebuoywavetide200m,chunks={'x':500,'y':500})
dsbuoywavetide300m=xr.open_dataset(filebuoywavetide300m,chunks={'x':500,'y':500})
dsbuoywavetide400m=xr.open_dataset(filebuoywavetide400m,chunks={'x':500,'y':500})
dsbuoywavetide500m=xr.open_dataset(filebuoywavetide500m,chunks={'x':500,'y':500})
dsbuoywavetide1000m=xr.open_dataset(filebuoywavetide1000m,chunks={'x':500,'y':500})
dsbuoywavetide1500m=xr.open_dataset(filebuoywavetide1500m,chunks={'x':500,'y':500})
dsbuoywavetide2000m=xr.open_dataset(filebuoywavetide2000m,chunks={'x':500,'y':500})
dsbuoywavetide2500m=xr.open_dataset(filebuoywavetide2500m,chunks={'x':500,'y':500})
dsbuoywavetide3000m=xr.open_dataset(filebuoywavetide3000m,chunks={'x':500,'y':500})
dsbuoywavetide3500m=xr.open_dataset(filebuoywavetide3500m,chunks={'x':500,'y':500})

dsN2tide=xr.open_dataset(fileN2tide,chunks={'x':500,'y':500})

# %%
dsUwavenotide100m=xr.open_dataset(fileUwavenotide100m,chunks={'x':500,'y':500})
dsUwavenotide200m=xr.open_dataset(fileUwavenotide200m,chunks={'x':500,'y':500})
dsUwavenotide300m=xr.open_dataset(fileUwavenotide300m,chunks={'x':500,'y':500})
dsUwavenotide400m=xr.open_dataset(fileUwavenotide400m,chunks={'x':500,'y':500})
dsUwavenotide500m=xr.open_dataset(fileUwavenotide500m,chunks={'x':500,'y':500})
dsUwavenotide1000m=xr.open_dataset(fileUwavenotide1000m,chunks={'x':500,'y':500})
dsUwavenotide1500m=xr.open_dataset(fileUwavenotide1500m,chunks={'x':500,'y':500})
dsUwavenotide2000m=xr.open_dataset(fileUwavenotide2000m,chunks={'x':500,'y':500})
dsUwavenotide2500m=xr.open_dataset(fileUwavenotide2500m,chunks={'x':500,'y':500})
dsUwavenotide3000m=xr.open_dataset(fileUwavenotide3000m,chunks={'x':500,'y':500})
dsUwavenotide3500m=xr.open_dataset(fileUwavenotide3500m,chunks={'x':500,'y':500})

dsVwavenotide100m=xr.open_dataset(fileVwavenotide100m,chunks={'x':500,'y':500})
dsVwavenotide200m=xr.open_dataset(fileVwavenotide200m,chunks={'x':500,'y':500})
dsVwavenotide300m=xr.open_dataset(fileVwavenotide300m,chunks={'x':500,'y':500})
dsVwavenotide400m=xr.open_dataset(fileVwavenotide400m,chunks={'x':500,'y':500})
dsVwavenotide500m=xr.open_dataset(fileVwavenotide500m,chunks={'x':500,'y':500})
dsVwavenotide1000m=xr.open_dataset(fileVwavenotide1000m,chunks={'x':500,'y':500})
dsVwavenotide1500m=xr.open_dataset(fileVwavenotide1500m,chunks={'x':500,'y':500})
dsVwavenotide2000m=xr.open_dataset(fileVwavenotide2000m,chunks={'x':500,'y':500})
dsVwavenotide2500m=xr.open_dataset(fileVwavenotide2500m,chunks={'x':500,'y':500})
dsVwavenotide3000m=xr.open_dataset(fileVwavenotide3000m,chunks={'x':500,'y':500})
dsVwavenotide3500m=xr.open_dataset(fileVwavenotide3500m,chunks={'x':500,'y':500})

dsWwavenotide100m=xr.open_dataset(fileWwavenotide100m,chunks={'x':500,'y':500})
dsWwavenotide200m=xr.open_dataset(fileWwavenotide200m,chunks={'x':500,'y':500})
dsWwavenotide300m=xr.open_dataset(fileWwavenotide300m,chunks={'x':500,'y':500})
dsWwavenotide400m=xr.open_dataset(fileWwavenotide400m,chunks={'x':500,'y':500})
dsWwavenotide500m=xr.open_dataset(fileWwavenotide500m,chunks={'x':500,'y':5001})
dsWwavenotide1000m=xr.open_dataset(fileWwavenotide1000m,chunks={'x':500,'y':500})
dsWwavenotide1500m=xr.open_dataset(fileWwavenotide1500m,chunks={'x':500,'y':500})
dsWwavenotide2000m=xr.open_dataset(fileWwavenotide2000m,chunks={'x':500,'y':500})
dsWwavenotide2500m=xr.open_dataset(fileWwavenotide2500m,chunks={'x':500,'y':500})
dsWwavenotide3000m=xr.open_dataset(fileWwavenotide3000m,chunks={'x':500,'y':500})
dsWwavenotide3500m=xr.open_dataset(fileWwavenotide3500m,chunks={'x':500,'y':500})

dsbuoywavenotide100m=xr.open_dataset(filebuoywavenotide100m,chunks={'x':500,'y':500})
dsbuoywavenotide200m=xr.open_dataset(filebuoywavenotide200m,chunks={'x':500,'y':500})
dsbuoywavenotide300m=xr.open_dataset(filebuoywavenotide300m,chunks={'x':500,'y':500})
dsbuoywavenotide400m=xr.open_dataset(filebuoywavenotide400m,chunks={'x':500,'y':500})
dsbuoywavenotide500m=xr.open_dataset(filebuoywavenotide500m,chunks={'x':500,'y':500})
dsbuoywavenotide1000m=xr.open_dataset(filebuoywavenotide1000m,chunks={'x':500,'y':500})
dsbuoywavenotide1500m=xr.open_dataset(filebuoywavenotide1500m,chunks={'x':500,'y':500})
dsbuoywavenotide2000m=xr.open_dataset(filebuoywavenotide2000m,chunks={'x':500,'y':500})
dsbuoywavenotide2500m=xr.open_dataset(filebuoywavenotide2500m,chunks={'x':500,'y':500})
dsbuoywavenotide3000m=xr.open_dataset(filebuoywavenotide3000m,chunks={'x':500,'y':500})
dsbuoywavenotide3500m=xr.open_dataset(filebuoywavenotide3500m,chunks={'x':500,'y':500})

dsN2notide=xr.open_dataset(fileN2notide,chunks={'x':500,'y':500})

# %%
ff=dsff.ff[0,1049:2240,3629:4410]

# %%
Uwavetide100m=dsUwavetide100m.vozocrtx_wave
Uwavetide200m=dsUwavetide200m.vozocrtx_wave
Uwavetide300m=dsUwavetide300m.vozocrtx_wave
Uwavetide400m=dsUwavetide400m.vozocrtx_wave
Uwavetide500m=dsUwavetide500m.vozocrtx_wave
Uwavetide1000m=dsUwavetide1000m.vozocrtx_wave
Uwavetide1500m=dsUwavetide1500m.vozocrtx_wave
Uwavetide2000m=dsUwavetide2000m.vozocrtx_wave
Uwavetide2500m=dsUwavetide2500m.vozocrtx_wave
Uwavetide3000m=dsUwavetide3000m.vozocrtx_wave
Uwavetide3500m=dsUwavetide3500m.vozocrtx_wave

Vwavetide100m=dsVwavetide100m.vomecrty_wave
Vwavetide200m=dsVwavetide200m.vomecrty_wave
Vwavetide300m=dsVwavetide300m.vomecrty_wave
Vwavetide400m=dsVwavetide400m.vomecrty_wave
Vwavetide500m=dsVwavetide500m.vomecrty_wave
Vwavetide1000m=dsVwavetide1000m.vomecrty_wave
Vwavetide1500m=dsVwavetide1500m.vomecrty_wave
Vwavetide2000m=dsVwavetide2000m.vomecrty_wave
Vwavetide2500m=dsVwavetide2500m.vomecrty_wave
Vwavetide3000m=dsVwavetide3000m.vomecrty_wave
Vwavetide3500m=dsVwavetide3500m.vomecrty_wave

Wwavetide100m=dsWwavetide100m.vovecrtz_wave
Wwavetide200m=dsWwavetide200m.vovecrtz_wave
Wwavetide300m=dsWwavetide300m.vovecrtz_wave
Wwavetide400m=dsWwavetide400m.vovecrtz_wave
Wwavetide500m=dsWwavetide500m.vovecrtz_wave
Wwavetide1000m=dsWwavetide1000m.vovecrtz_wave
Wwavetide1500m=dsWwavetide1500m.vovecrtz_wave
Wwavetide2000m=dsWwavetide2000m.vovecrtz_wave
Wwavetide2500m=dsWwavetide2500m.vovecrtz_wave
Wwavetide3000m=dsWwavetide3000m.vovecrtz_wave
Wwavetide3500m=dsWwavetide3500m.vovecrtz_wave

buoywavetide100m=dsbuoywavetide100m.sobuoy_wave
buoywavetide200m=dsbuoywavetide200m.sobuoy_wave
buoywavetide300m=dsbuoywavetide300m.sobuoy_wave
buoywavetide400m=dsbuoywavetide400m.sobuoy_wave
buoywavetide500m=dsbuoywavetide500m.sobuoy_wave
buoywavetide1000m=dsbuoywavetide1000m.sobuoy_wave
buoywavetide1500m=dsbuoywavetide1500m.sobuoy_wave
buoywavetide2000m=dsbuoywavetide2000m.sobuoy_wave
buoywavetide2500m=dsbuoywavetide2500m.sobuoy_wave
buoywavetide3000m=dsbuoywavetide3000m.sobuoy_wave
buoywavetide3500m=dsbuoywavetide3500m.sobuoy_wave

N2tide=dsN2tide.vobn2

# %%
Uwavenotide100m=dsUwavenotide100m.vozocrtx_wave
Uwavenotide200m=dsUwavenotide200m.vozocrtx_wave
Uwavenotide300m=dsUwavenotide300m.vozocrtx_wave
Uwavenotide400m=dsUwavenotide400m.vozocrtx_wave
Uwavenotide500m=dsUwavenotide500m.vozocrtx_wave
Uwavenotide1000m=dsUwavenotide1000m.vozocrtx_wave
Uwavenotide1500m=dsUwavenotide1500m.vozocrtx_wave
Uwavenotide2000m=dsUwavenotide2000m.vozocrtx_wave
Uwavenotide2500m=dsUwavenotide2500m.vozocrtx_wave
Uwavenotide3000m=dsUwavenotide3000m.vozocrtx_wave
Uwavenotide3500m=dsUwavenotide3500m.vozocrtx_wave

Vwavenotide100m=dsVwavenotide100m.vomecrty_wave
Vwavenotide200m=dsVwavenotide200m.vomecrty_wave
Vwavenotide300m=dsVwavenotide300m.vomecrty_wave
Vwavenotide400m=dsVwavenotide400m.vomecrty_wave
Vwavenotide500m=dsVwavenotide500m.vomecrty_wave
Vwavenotide1000m=dsVwavenotide1000m.vomecrty_wave
Vwavenotide1500m=dsVwavenotide1500m.vomecrty_wave
Vwavenotide2000m=dsVwavenotide2000m.vomecrty_wave
Vwavenotide2500m=dsVwavenotide2500m.vomecrty_wave
Vwavenotide3000m=dsVwavenotide3000m.vomecrty_wave
Vwavenotide3500m=dsVwavenotide3500m.vomecrty_wave

Wwavenotide100m=dsWwavenotide100m.vovecrtz_wave
Wwavenotide200m=dsWwavenotide200m.vovecrtz_wave
Wwavenotide300m=dsWwavenotide300m.vovecrtz_wave
Wwavenotide400m=dsWwavenotide400m.vovecrtz_wave
Wwavenotide500m=dsWwavenotide500m.vovecrtz_wave
Wwavenotide1000m=dsWwavenotide1000m.vovecrtz_wave
Wwavenotide1500m=dsWwavenotide1500m.vovecrtz_wave
Wwavenotide2000m=dsWwavenotide2000m.vovecrtz_wave
Wwavenotide2500m=dsWwavenotide2500m.vovecrtz_wave
Wwavenotide3000m=dsWwavenotide3000m.vovecrtz_wave
Wwavenotide3500m=dsWwavenotide3500m.vovecrtz_wave

buoywavenotide100m=dsbuoywavenotide100m.sobuoy_wave
buoywavenotide200m=dsbuoywavenotide200m.sobuoy_wave
buoywavenotide300m=dsbuoywavenotide300m.sobuoy_wave
buoywavenotide400m=dsbuoywavenotide400m.sobuoy_wave
buoywavenotide500m=dsbuoywavenotide500m.sobuoy_wave
buoywavenotide1000m=dsbuoywavenotide1000m.sobuoy_wave
buoywavenotide1500m=dsbuoywavenotide1500m.sobuoy_wave
buoywavenotide2000m=dsbuoywavenotide2000m.sobuoy_wave
buoywavenotide2500m=dsbuoywavenotide2500m.sobuoy_wave
buoywavenotide3000m=dsbuoywavenotide3000m.sobuoy_wave
buoywavenotide3500m=dsbuoywavenotide3500m.sobuoy_wave

N2notide=dsN2notide.vobn2

# %%
navlat= dsbuoywavenotide100m['nav_lat']
navlon= dsbuoywavenotide100m['nav_lon']

box=(-31,-28,33,36)
domain=(box[0]<navlon)*(navlon<box[1])*(box[2]<navlat)*(navlat<box[3])
where=np.where(domain)

lats=navlat[where]
lons=navlon[where]

ind = np.unravel_index(np.argmin(lats, axis=None), lats.shape)
jmin = where[0][ind[0]]
ind = np.unravel_index(np.argmax(lats, axis=None), lats.shape)
jmax = where[0][ind[0]]
ind = np.unravel_index(np.argmin(lons, axis=None), lons.shape)
imin = where[1][ind[1]]
ind = np.unravel_index(np.argmax(lons, axis=None), lons.shape)
imax = where[1][ind[1]]
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/indexing.py:1174: PerformanceWarning: Slicing with an out-of-order index is generating 216 times more chunks
#   value = value[(slice(None),) * axis + (subkey,)]

# %%
Uwavetide100m.shape
# Out:
# (744, 1, 1191, 781)

# %%
meanU=np.nanmean(Uwavetide100m[:,0,jmin:jmax+1,imin:imax+1].values)
meanW=np.nanmean(Wwavetide100m[:,0,jmin:jmax+1,imin:imax+1].values)
meanV=np.nanmean(Uwavetide100m[:,0,jmin:jmax+1,imin:imax+1].values)
meanb=np.nanmean(Uwavetide100m[:,0,jmin:jmax+1,imin:imax+1].values)
meanf=np.nanmean(ff[jmin:jmax+1,imin:imax+1].values)
meanN=np.nanmean(N2notide[:,30,jmin:jmax+1,imin:imax+1].values)

Epx=meanU*meanW-meanf*meanV*meanb/meanN
Epy=meanV*meanW+meanf*meanU*meanb/meanN


print 'mean U =', meanU
print 'mean W =', meanW
print 'mean f =', meanf
print 'mean V =', meanV
print 'mean b =', meanb
print 'mean N2 =', meanN
print 'uw =',meanU*meanW
print 'fvb/N', meanf*meanV*meanb/meanN
print 'Epx =', Epx
print 'vw =',meanV*meanW
print 'fub/N', meanf*meanU*meanb/meanN
print 'Epy =', Epy
# Out:
# mean U = 1.8694123e-05
# mean W = 1.06190114e-08
# mean f = 8.263467374125716e-05
# mean V = 1.8694123e-05
# mean b = 1.8694123e-05
# mean N2 = 5.37368e-05
# uw = 1.9851311e-13
# fvb/N 5.374037929653595e-10
# Epx = -5.372052798572811e-10
# vw = 1.9851311e-13
# fub/N 5.374037929653595e-10
# Epy = 5.37602306073438e-10

# %%
meanU=np.nanmean(Uwavetide1000m[:,0,jmin:jmax+1,imin:imax+1].values)
meanW=np.nanmean(Wwavetide1000m[:,0,jmin:jmax+1,imin:imax+1].values)
meanV=np.nanmean(Uwavetide1000m[:,0,jmin:jmax+1,imin:imax+1].values)
meanb=np.nanmean(Uwavetide1000m[:,0,jmin:jmax+1,imin:imax+1].values)
meanf=np.nanmean(ff[jmin:jmax+1,imin:imax+1].values)
meanN=np.nanmean(N2notide[:,30,jmin:jmax+1,imin:imax+1].values)

Epx=meanU*meanW-meanf*meanV*meanb/(meanN*meanN)
Epy=meanV*meanW+meanf*meanU*meanb/(meanN*meanN)


print 'mean U =', meanU
print 'mean W =', meanW
print 'mean f =', meanf
print 'mean V =', meanV
print 'mean b =', meanb
print 'mean N2 =', meanN*meanN
print 'uw =',meanU*meanW
print 'fvb/N', meanf*meanV*meanb/(meanN*meanN)
print 'Epx =', Epx
print 'vw =',meanV*meanW
print 'fub/N', meanf*meanU*meanb/(meanN*meanN)
print 'Epy =', Epy
# Out:
# mean U = 1.5966165e-05
# mean W = 4.663835e-08
# mean f = 8.263467374125716e-05
# mean V = 1.5966165e-05
# mean b = 1.5966165e-05
# mean N2 = 2.8876437e-09
# uw = 7.446356e-13
# fvb/N 7.2949099807901975e-06
# Epx = -7.294909236154616e-06
# vw = 7.446356e-13
# fub/N 7.2949099807901975e-06
# Epy = 7.294910725425779e-06
